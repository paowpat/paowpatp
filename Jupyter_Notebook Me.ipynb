# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio
# ====

# %% [markdown]
# **Paowpat Pensupa**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because I'm interested in data and also machine learning. I want to apply these things in my real life for better decision-making. For example, I want to make a decision of what transportation should I take for going to my campus in the city. I want to know how other people think about making this decision, what parameter has influence in their decision. I'll make use of those overall dataset to create model by ML/DL to see a pattern.*

# %% [markdown]
# ### Divide 3 by 2 and check if the result type is float

# %%
type(3/2) == float
# Out:
# True

# %% [markdown]
# |     Table     |    Column1    |    Column2    |
# | ------------- | ------------- | ------------- |
# |     Row1      |   Element 11  |   Element 12  |
# |     Row2      |   Element 21  |   Element 22  |
# |     Row3      |   Element 31  |   Element 32  |
#
# Horizontal Rule
#
# ***
#
# `code/syntax highlighting`
